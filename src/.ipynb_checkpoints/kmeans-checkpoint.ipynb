# %%
import pandas as pd
import numpy as np
from scipy.sparse import *
from collections import Counter
from heapq import nsmallest
import re
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction import DictVectorizer
from sklearn.cluster import KMeans
from sklearn.externals import joblib

# %%
path = '../data/eventclouds.npy'

data = np.load(path)

# %%
#data
# Out:
# array({UUID('7fc58c00-83dc-44cd-a2e8-f3cb0778c573'): {'resources': ['Berlin', 'Symbiosis', 'Grunge', 'California', 'Popmusic', 'Existentialism', 'Anxiety', 'Electricguitar', 'Synthesizer'], 'types': ['SchemaPlaceDBpediaPlaceDBpediaPopulatedPlaceDBpediaRegionSchemaAdministrativeAreaDBpediaAdministrativeRegion', 'DBpediaTopicalConceptDBpediaGenreDBpediaMusicGenre', 'SchemaPlaceDBpediaPlaceDBpediaPopulatedPlaceDBpediaRegionSchemaAdministrativeAreaDBpediaAdministrativeRegion', 'DBpediaTopicalConceptDBpediaGenreDBpediaMusicGenre'], 'broader': ['CategorySchoolsofthought', 'CategoryScienceandtechnologyintheUnitedStates', 'CategoryWikipediacategoriesnamedaftercapitals', 'CategoryUnitedStates', 'CategoryMovements', 'CategoryAlternativerock', 'CategoryCulturebyregion', 'CategoryPitchmusic', 'Category20thcenturyinmusic', 'CategoryContemporaryphilosophy', 'CategoryMusicofthePacificNorthwest', 'CategoryAmericanstylesofmusic', 'CategoryStatesoftheWestCoastoftheUnitedStates', 'CategoryMusicofWashingtonstate', 'CategoryJazzinstruments', 'CategoryMusicalsubgenresbygenre', 'CategoryClassicalstudies', 'CategoryPhilosophybyfield', 'CategoryModernphilosophy', 'CategoryElectronicmusicalinstruments', 'CategoryMetaphysics', 'CategoryHiphop', 'CategoryNorthAmericanmusicalinstruments', 'CategorySocialtheories', 'Category1990sinmusic', 'CategoryEmotions', 'CategoryCitiesinEurope', 'CategoryKeyboardinstruments', 'Category19thcenturyphilosophy', 'CategoryMusicalanalysis', 'CategoryPoliticalculture', 'CategoryMusicbydecade', 'CategorySubdivisionsoftheUnitedStates', 'Category1990sinNorthAmerica', 'CategoryStatesofGermany', 'CategoryDecadesintheUnitedStates', 'CategoryContemporaryhistory', 'CategoryCultureofSeattleWashington', 'CategoryPositivepsychology', 'CategoryWashingtonstateculture', 'CategoryMusicofUnitedStatessubdivisions', 'Category1980sinNorthAmerica', 'CategorySocialphilosophy', 'CategoryWestCoastoftheUnitedStates', 'CategoryCountries', 'CategoryAmericanmusicbycity', 'CategoryStatesoftheUnitedStates', 'CategoryPsychologicalconcepts', 'Category20thcenturyintheUnitedStates', 'CategorySelf', 'CategoryPoliticaltheories', 'CategoryModernity', 'CategoryMusicperformance', 'CategoryHarmony', 'Category1990sbycountry', 'CategoryGovernmentinstitutions', 'CategoryGermanstatecapitals', 'CategoryPopmusicgenres', 'Category19thcentury', 'CategoryNorthAmericanstylesofmusic', 'CategoryFirstleveladministrativecountrysubdivisions', 'CategoryAlternativerockgenres', 'Category20thcenturyphilosophy', 'CategoryHanseaticLeague', 'CategoryPhilosophicalmovements', 'CategoryMedievalcities', 'CategoryCapitalsinEurope', 'CategoryEmotion', 'CategorySociologicalparadigms', 'CategoryEvolutionarilysignificantbiologicalphenomena', 'CategoryIndividualism', 'CategoryPopularmusic', 'CategoryPersonallife', 'CategoryPsychologicalstates', 'CategoryHistoryofphilosophy', 'CategoryCulturaltrends', 'CategoryAmericanmusic', 'CategoryContinentalphilosophy', 'CategoryCivilizations', 'CategoryBiologicalinteractions', 'CategoryMusictechnology', 'CategoryAccompaniment', 'CategoryCitiesbytype', 'CategoryCapitalsofcountrysubdivisionsinEurope', 'CategoryCulturalanthropology', 'CategoryAmplifiedinstruments', 'CategorySociologicalterminology', 'CategoryCitiesinGermany', 'Category1990sfadsandtrends', 'CategoryPhilosophyoflife', 'CategoryHistoryoftheUnitedStates1991present', 'CategoryMusicalinstruments', 'CategoryPunkrockgenres', 'Category20thcentury', 'CategoryInventionsbycountry', 'CategoryMusicgenres', 'Category1980sbycountry', 'CategoryContemporarymusic', 'CategoryGermancitystates', 'CategoryCapitals', 'CategoryRockmusicgenres', 'CategoryMusicofSeattleWashington', 'CategoryAutonomy', 'CategoryWikipediacategoriesnamedafterpopulatedplacesinGermany', 'CategoryGuitars', 'CategoryLife', 'CategoryMetaphysicaltheories', 'CategoryCultureofthePacificNorthwest', 'CategoryAbnormalpsychology', 'CategoryHiphopmusicians', 'CategoryRhythmandmeter', 'CategoryMusicalsubcultures', 'CategoryPhilosophicaltheories', 'Cate ...

# %%
def get_words_from_data(data):
    cat_list = []
    for id, event in data.item().items():
        # event
        for feature, resources in event.items():
            # dbpedia answers    
            cat_list.append(resources)

    # flatten
    return [item for sublist in cat_list for item in sublist]

# %%
def get_most_common(words, n):
    c = Counter(words)
    return [x[0] for x in c.most_common(n)]

# %%
word_list = get_words_from_data(data)
stop = get_most_common(word_list, 70)
stop.append('DULowlAgent')
stop.append('Agent')

# %%
def prepare_data(data, filter_data=[]):
    X = []
    for key, values in data.item().items():
        #event
        row = {}
        for feature, resources in values.items():
            if filter_data:
                res = [x for x in resources if x not in filter_data]
            else:
                res = resources
            
            # change data format for vectorizing
            tmp = [feature + '=' + x for x in res]
            
            for entry in tmp:
                row[entry] = True
        X.append(row)
    return X

# %%
D = prepare_data(data, stop)

# %%
v = DictVectorizer(sparse=True)
X = v.fit_transform(D)

# %%
feature_occ = v.get_feature_names()

# %%
from sklearn.cluster import KMeans

num_clusters = 5

km = KMeans(n_clusters=num_clusters)

# %time km.fit(X)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 82.9 ms, sys: 2.91 ms, total: 85.8 ms
# Wall time: 90.3 ms

# %%
test = km.transform(X)

# %%
def calculate_confidence(transformed_x):
    # calculate confidence
    scores = []
    for distances in transformed_x:
        #print(distances)
        dist = 100 - distances
        #norm = [float(i)/sum(dist) for i in dist]
        #print(norm)
        #confidence = min(norm)
        
        #use min dist for now
        confidence = min(distances)
        scores.append(confidence)
        
    return scores

# %%
confidences = calculate_confidence(test)

# %%
frame = pd.DataFrame(data.item()).transpose()
frame.columns = ['broader', 'categories', 'resources', 'subClassOf', 'types']
frame['cluster'] = pd.Series(clusters).values
frame['min_dist'] = pd.Series(confidences).values
frame.reset_index(level=0, inplace=True)

# %%
frame.head()
# Out:
#                                   index  \
# 0  2fe70aaa-b666-4eb4-9e6e-aff62e552492
# 1  3d64c073-3c3e-4a83-be74-11ccf5e36230
# 2  4365dd09-c439-46b0-abee-c487c5293245
# 3  4bd852de-07bb-4c94-8aef-8d80fb68932a
# 4  67395a5c-b1ca-4a35-91bd-2d22c9a611e6
#
#                                              broader  \
# 0  [CategoryEthnicgroupsinIndia, CategoryReligiou...
# 1  [CategoryCloudcomputing, CategorySocialsoftwar...
# 2  [CategoryCohortstudies, CategoryEpidemiology, ...
# 3  [CategoryEducationbysubject, CategoryEuthenics...
# 4  [CategoryAptitude, CategoryVisualarts, Categor...
#
#                                           categories  \
# 0  [CategoryHindurevivalists, CategoryYogatextsan...
# 1  [CategoryAndroidoperatingsystemsoftware, Categ...
# 2  [CategoryDesignofexperiments, Category5thcentu...
# 3  [CategoryBrandenburg, CategoryNUTS1statistical...
# 4  [CategoryCreativity, CategoryIndustrialdesign,...
#
#                                            resources  \
# 0                [ChaitanyaMahaprabhu, BhagavadGita]
# 1  [Smartphone, Mobilecomputing, Internet, Livest...
# 2  [Longitudinalstudy, Proclus, Speakerpolitics, ...
# 3                 [Brandenburg, Vocationaleducation]
# 4                                   [Designthinking]
#
#                                           subClassOf  \
# 0  [Communication100033020, WikicatDevoteesOfJaga...
# 1  [Q486972, Organization108008335, WikicatUniver...
# 2  [Set107996689, Q486972, Scholar110557854, Wiki...
# 3  [Location100027167, Q486972, YagoGeoEntity, Pl...
# 4                                                 []
#
#                                                types  cluster  min_dist
# 0                                                 []        0  5.473573
# 1  [DBpediaAgentSchemaOrganizationDBpediaOrganisa...        1  0.000000
# 2  [PersonDBpediaPersonDBpediaPhilosopher, Schema...        3  0.000000
# 3  [SchemaPlaceDBpediaPlaceDBpediaPopulatedPlaceD...        0  6.289674
# 4                                                 []        4  0.000000

# %%
lookup = np.load('../data/event_lookup.npy')
lookup = pd.DataFrame(lookup, columns = ['index', 'title'])
lookup.head()

#frame.loc['-KcBAZuiALnRgx2KE0yN']
#df.head()
# Out:
#                                   index  \
# 0  68d9d916-f751-45cd-ab58-cb409f6d9aee
# 1  04d7a732-6b66-4b9f-ae16-d822a5410d59
# 2  fc066fd1-4e49-4d8a-a2a2-04d5ecb15d1e
# 3  f1c1944a-b044-4851-85b7-c4073c7ab3fa
# 4  67395a5c-b1ca-4a35-91bd-2d22c9a611e6
#
#                                                title
# 0        Voice Yoga Singing Class with Kara Johnstad
# 1  Kostenloses Webinar: Schmerzfrei mit dem Rennr...
# 2               HZT Open Lecture: Stephanie Schröder
# 3   SPOWI Fasching - "80er/90er - Spowi is a dancer"
# 4                                     Open House Day

# %%
hansi = pd.merge(frame, lookup, how='left', on='index')

# %%
hansi['cluster'].value_counts()
# Out:
# 0    5
# 4    1
# 3    1
# 2    1
# 1    1
# Name: cluster, dtype: int64

# %%
def clean_string(string, regex=r'[a-zA-Z0-9]*='):
    """
    clean string by removing non chars
    """
    tmp = re.sub(regex, '', string)
    return re.sub('(?<=[a-zA-Z])\d+$', '', tmp)

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()

top_n = 15

order_centroids = km.cluster_centers_.argsort()[:, ::-1]
for i in range(num_clusters):
    print("Cluster: {i}, Entries: {e}, top {t} features: \n".format(i = i, e = hansi['cluster'].value_counts()[i], t = top_n))
    for ind in order_centroids[i, :top_n]:
        #print(ind)
        feature = v.get_feature_names()[ind]
        print(clean_string(feature))
    print()
    print()
# Out:
# Top terms per cluster:
#
# Cluster: 0, Entries: 5, top 15 features:
#
# CategoryIndianphilosophy
# ReligiousPerson
# CategoryEthnicgroupsinIndia
# CategoryEthnicgroupsinBangladesh
# CategoryPerformersofHindumusic
# Q
# Q
# Q
# Q
# CategoryEpicpoemsinSanskrit
# CategoryPersonallife
# Region
# Religious
# ReligiousLeader
# CategoryKurukshetra
#
#
# Cluster: 1, Entries: 1, top 15 features:
#
# ATVMusicPublishing
# Digit
# Executive
# Category21stcenturyAmericansingers
# Category21stcenturyAmericanwriters
# Category21stcenturywomenwriters
# Entertainer
# CategoryElectronicmusicians
# CategoryElectronicmusiciansbynationality
# CategoryElectronicmusicsingers
# CategoryPerforminggroupsestablishedin
# CategoryElektraRecordsartists
# Drummer
# CategoryPeopleofFrenchdescent
# CategoryEntertainmentevents
#
#
# Cluster: 2, Entries: 1, top 15 features:
#
# SchemaPlaceDBpediaPlaceDBpediaPopulatedPlaceSchemaCountryDBpediaCountry
# CategoryHumans
# CategoryLanguagefamilies
# CategoryLanguagesbycountry
# CategoryLanguagesbywordorder
# CategoryLanguagesofAfrica
# CategoryLanguagesofAsia
# CategoryRemotedesktopprotocols
# CategoryReligionarticlesneedingexpertattention
# CategoryLanguagesofCentralAmerica
# CategoryLanguagesofChina
# CategoryLanguagesofEurope
# CategoryLanguagesofNewGuinea
# CategoryLanguagesofNorthAmerica
# CategoryLanguagesofOceania
#
#
# Cluster: 3, Entries: 1, top 15 features:
#
# Stream
# CategoryEssen
# Network
# CategoryInformationappliances
# CategoryFederalwaterwaysinGermany
# Organisation
# Organization
# Organization
# PersonalComputer
# CategoryIOSsoftware
# CategoryHypertext
# PortableComputer
# CategoryEuropeanseas
# CategoryEuropeanUnionexternalborders
# Protocol
#
#
# Cluster: 4, Entries: 1, top 15 features:
#
# Category5thcenturyByzantinepeople
# CategoryScienceexperiments
# CategoryScholarsofancientGreekphilosophy
# CategoryScholarsbyphilosopher
# CategoryMystics
# Mathematician
# CategoryPositionsofauthority
# Method
# CategoryPhilosophersofmathematics
# CategoryNeoplatonists
# CategoryRomanpeoplebycentury
# WikicatGreekMathematicians
# WikicatGovernmentOccupations
# Mystic
# CategoryPeoplefromConstantinople

# %%
from sklearn.externals import joblib

joblib.dump(km,  '../data/doc_cluster.pkl')
#km = joblib.load('../data/doc_cluster.pkl')
# Out:
# ['../data/doc_cluster.pkl']

# %%
plt.figure(figsize=(10, 6))
liste = []
labels = []
for i in range(num_clusters):
    #print(hansi.loc[hansi['cluster'] == i]['min_dist'].values)
    tmp = hansi.loc[hansi['cluster'] == i]['min_dist'].values
    liste.append(tmp)
    labels.append('cluster {}'.format(i))
plt.boxplot(liste)
plt.xticks(range(1,11), labels, rotation='vertical')
plt.show()

# %%
bla = hansi.loc[hansi['cluster'] == 9]['min_dist']
print(bla)
#bla.sort_values(inplace=True)
#bla
# Out:
# Series([], Name: min_dist, dtype: float64)

# %%
top_5 = hansi.sort_values(by=['min_dist'],ascending=True).groupby('cluster').head(5)

# %%
top_5.loc[top_5['cluster'] == 1]['title']
# Out:
# 1    D1g1tale H0chschule – Die Zukunft des Lernens ...
# Name: title, dtype: object

# %%
n = 10

print('Top {} titles per cluster:'.format(n))
print()
for i in range(num_clusters):
    print('cluster {}:'.format(i))
    tmp = hansi.sort_values(by=['min_dist'],ascending=True).groupby('cluster').head(n)
    titles = tmp.loc[tmp['cluster'] == i]['title']
    for entry in titles:
        print(entry)
    print()
# Out:
# Top 10 titles per cluster:
#
# cluster 0:
# Voice Yoga Singing Class with Kara Johnstad
# Gaura Arati
# Ausstellungseröffnung "Brandenburger Reflexionen"
# SPOWI Fasching - "80er/90er - Spowi is a dancer"
# Eltern-Schüler-Sprechabend
#
# cluster 1:
# D1g1tale H0chschule – Die Zukunft des Lernens und Lehrens
#
# cluster 2:
# HZT Open Lecture: Stephanie Schröder
#
# cluster 3:
# Psychologie Kolloquium: Mediation im Rechtswesen
#
# cluster 4:
# Open House Day

# %%
sums = hansi['min_dist'].groupby(hansi.cluster).sum()
plt.axis('equal')
plt.pie(sums, labels=['cluster {}'.format(x) for x in sums.index])
plt.show()

# %%
hansi.loc[hansi['cluster'] == 9]['min_dist']
# Out:
# Series([], Name: min_dist, dtype: float64)
